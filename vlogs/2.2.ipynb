# %%
import torch
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("/aul/homes/zyin007/zb/assignment5-alignment/model/Qwen2.5-1.5B")

print(tokenizer.pad_token_id)
print(tokenizer.eos_token)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import torch
#       2 from transformers import AutoTokenizer
#       3 tokenizer = AutoTokenizer.from_pretrained("/aul/homes/zyin007/zb/assignment5-alignment/model/Qwen2.5-1.5B")
#
# ModuleNotFoundError: No module named 'torch'
